# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  3.125594 -2.300692  0.498162  2.891502  1.999631       0
# 1  0.502839  1.627262  1.620235  1.082211 -3.131136       1
# 2  0.978954 -0.867851 -1.693002  1.653024  0.394949       0
# 3  1.430182 -2.582397  1.431562 -1.916530  3.685106       1
# 4  0.441591  0.196783 -2.182895 -0.426743  0.768476       0

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[0])
plt.show()

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features=2, random_state=188161931),
#  DecisionTreeClassifier(max_features=2, random_state=568406394),
#  DecisionTreeClassifier(max_features=2, random_state=1563519490),
#  DecisionTreeClassifier(max_features=2, random_state=248731810),
#  DecisionTreeClassifier(max_features=2, random_state=522694759),
#  DecisionTreeClassifier(max_features=2, random_state=799484598),
#  DecisionTreeClassifier(max_features=2, random_state=254762432),
#  DecisionTreeClassifier(max_features=2, random_state=1037086734),
#  DecisionTreeClassifier(max_features=2, random_state=1117991693),
#  DecisionTreeClassifier(max_features=2, random_state=1736817368),
#  DecisionTreeClassifier(max_features=2, random_state=970054029),
#  DecisionTreeClassifier(max_features=2, random_state=1475667020),
#  DecisionTreeClassifier(max_features=2, random_state=117746815),
#  DecisionTreeClassifier(max_features=2, random_state=995605382),
#  DecisionTreeClassifier(max_features=2, random_state=1582396641),
#  DecisionTreeClassifier(max_features=2, random_state=998620209),
#  DecisionTreeClassifier(max_features=2, random_state=910462916),
#  DecisionTreeClassifier(max_features=2, random_state=1947177727),
#  DecisionTreeClassifier(max_features=2, random_state=1135191973),
#  DecisionTreeClassifier(max_features=2, random_state=1220561580),
#  DecisionTreeClassifier(max_features=2, random_state=350090021),
#  DecisionTreeClassifier(max_features=2, random_state=1953462861),
#  DecisionTreeClassifier(max_features=2, random_state=1180279228),
#  DecisionTreeClassifier(max_features=2, random_state=713472274),
#  DecisionTreeClassifier(max_features=2, random_state=1333773689),
#  DecisionTreeClassifier(max_features=2, random_state=427885135),
#  DecisionTreeClassifier(max_features=2, random_state=1986382893),
#  DecisionTreeClassifier(max_features=2, random_state=1950722477),
#  DecisionTreeClassifier(max_features=2, random_state=815515381),
#  DecisionTreeClassifier(max_features=2, random_state=1513590314),
#  DecisionTreeClassifier(max_features=2, random_state=7361832),
#  DecisionTreeClassifier(max_features=2, random_state=375895305),
#  DecisionTreeClassifier(max_features=2, random_state=483718525),
#  DecisionTreeClassifier(max_features=2, random_state=805130941),
#  DecisionTreeClassifier(max_features=2, random_state=2001364315),
#  DecisionTreeClassifier(max_features=2, random_state=535581086),
#  DecisionTreeClassifier(max_features=2, random_state=447548853),
#  DecisionTreeClassifier(max_features=2, random_state=231461735),
#  DecisionTreeClassifier(max_features=2, random_state=972179384),
#  DecisionTreeClassifier(max_features=2, random_state=785749192),
#  DecisionTreeClassifier(max_features=2, random_state=1282169863),
#  DecisionTreeClassifier(max_features=2, random_state=2137054894),
#  DecisionTreeClassifier(max_features=2, random_state=546187849),
#  DecisionTreeClassifier(max_features=2, random_state=171938977),
#  DecisionTreeClassifier(max_features=2, random_state=1890871912),
#  DecisionTreeClassifier(max_features=2, random_state=2056702502),
#  DecisionTreeClassifier(max_features=2, random_state=614875292),
#  DecisionTreeClassifier(max_features=2, random_state=1284305036),
#  DecisionTreeClassifier(max_features=2, random_state=1052360433),
#  DecisionTreeClassifier(max_features=2, random_state=1696526231),
#  DecisionTreeClassifier(max_features=2, random_state=57633169),
#  DecisionTreeClassifier(max_features=2, random_state=1895511893),
#  DecisionTreeClassifier(max_features=2, random_state=448884476),
#  DecisionTreeClassifier(max_features=2, random_state=535728023),
#  DecisionTreeClassifier(max_features=2, random_state=817340036),
#  DecisionTreeClassifier(max_features=2, random_state=1048932972),
#  DecisionTreeClassifier(max_features=2, random_state=147554046),
#  DecisionTreeClassifier(max_features=2, random_state=1135170356),
#  DecisionTreeClassifier(max_features=2, random_state=1224464219),
#  DecisionTreeClassifier(max_features=2, random_state=1797889473),
#  DecisionTreeClassifier(max_features=2, random_state=432396963),
#  DecisionTreeClassifier(max_features=2, random_state=617353804),
#  DecisionTreeClassifier(max_features=2, random_state=405323674),
#  DecisionTreeClassifier(max_features=2, random_state=793573631),
#  DecisionTreeClassifier(max_features=2, random_state=119137401),
#  DecisionTreeClassifier(max_features=2, random_state=1339949526),
#  DecisionTreeClassifier(max_features=2, random_state=678638158),
#  DecisionTreeClassifier(max_features=2, random_state=666461623),
#  DecisionTreeClassifier(max_features=2, random_state=436077204),
#  DecisionTreeClassifier(max_features=2, random_state=1247761582),
#  DecisionTreeClassifier(max_features=2, random_state=413442703),
#  DecisionTreeClassifier(max_features=2, random_state=194608225),
#  DecisionTreeClassifier(max_features=2, random_state=1373219207),
#  DecisionTreeClassifier(max_features=2, random_state=2113870390),
#  DecisionTreeClassifier(max_features=2, random_state=509682818),
#  DecisionTreeClassifier(max_features=2, random_state=1899049296),
#  DecisionTreeClassifier(max_features=2, random_state=1222724977),
#  DecisionTreeClassifier(max_features=2, random_state=456356893),
#  DecisionTreeClassifier(max_features=2, random_state=1361965676),
#  DecisionTreeClassifier(max_features=2, random_state=277521590),
#  DecisionTreeClassifier(max_features=2, random_state=275157621),
#  DecisionTreeClassifier(max_features=2, random_state=1414441097),
#  DecisionTreeClassifier(max_features=2, random_state=245453265),
#  DecisionTreeClassifier(max_features=2, random_state=337794100),
#  DecisionTreeClassifier(max_features=2, random_state=2056987727),
#  DecisionTreeClassifier(max_features=2, random_state=2015818783),
#  DecisionTreeClassifier(max_features=2, random_state=285798820),
#  DecisionTreeClassifier(max_features=2, random_state=1506683856),
#  DecisionTreeClassifier(max_features=2, random_state=1964132338),
#  DecisionTreeClassifier(max_features=2, random_state=2135981343),
#  DecisionTreeClassifier(max_features=2, random_state=1699874110),
#  DecisionTreeClassifier(max_features=2, random_state=798778611),
#  DecisionTreeClassifier(max_features=2, random_state=2127100689),
#  DecisionTreeClassifier(max_features=2, random_state=1651145467),
#  DecisionTreeClassifier(max_features=2, random_state=1840453893),
#  DecisionTreeClassifier(max_features=2, random_state=609223381),
#  DecisionTreeClassifier(max_features=2, random_state=1378918116),
#  DecisionTreeClassifier(max_features=2, random_state=835693728),
#  DecisionTreeClassifier(max_features=2, random_state=1661174015),
#  DecisionTreeClassifier(max_features=2, random_state=1842205834)]
