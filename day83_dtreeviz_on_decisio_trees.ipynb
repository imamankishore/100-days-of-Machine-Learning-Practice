# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-2.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting graphviz>=0.9 (from dtreeviz)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pandas in c:\users\itsam\anaconda3\lib\site-packages (from dtreeviz) (2.2.2)
# Requirement already satisfied: numpy in c:\users\itsam\appdata\roaming\python\python312\site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\itsam\anaconda3\lib\site-packages (from dtreeviz) (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\itsam\anaconda3\lib\site-packages (from dtreeviz) (3.9.2)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pytest in c:\users\itsam\anaconda3\lib\site-packages (from dtreeviz) (7.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\itsam\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\itsam\anaconda3\lib\site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\itsam\anaconda3\lib\site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in c:\users\itsam\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\itsam\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: colorama in c:\users\itsam\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\itsam\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\itsam\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\itsam\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\itsam\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: colour, graphviz, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-2.2.2 graphviz-0.21

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz import * 
from IPython.display import Image , display_svg , SVG

# %%
from sklearn import tree

# %%
from sklearn.datasets import load_iris

# %%
clf = tree.DecisionTreeClassifier(max_depth=5)
iris = load_iris()

X_train = iris.data
y_train = iris.target

# %%
clf.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# ### Classification

# %%
viz = dtreeviz(clf, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# C:\Users\itsam\AppData\Local\Temp\ipykernel_19420\1042043249.py:1: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 viz = dtreeviz(clf,
#       2                X_train,
#       3                y_train,
#       4                feature_names=iris.feature_names,
#       5                class_names=["setosa", "versicolor", "virginica"])
#       6 viz
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\compatibility.py:254, in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     251 shadow_tree = ShadowDecTree.get_shadow_tree(tree_model, X_train, y_train, feature_names, target_name, class_names,
#     252                                             tree_index)
#     253 model = DTreeVizAPI(shadow_tree)
# --> 254 return model.view(precision, orientation,
#     255                   instance_orientation,
#     256                   show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X,
#     257                   max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize,
#     258                   fontname, title, title_fontsize, colors=colors, scale=scale)
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\trees.py:523, in DTreeVizAPI.view(self, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, leaftype, highlight_path, x, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     521 tmp = tempfile.gettempdir()
#     522 if x is not None:
# --> 523     path = self.shadow_tree.predict_path(x)
#     524     highlight_path = [n.id for n in path]
#     526 color_values = colors['classes'][n_classes]
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:340, in ShadowDecTree.predict_path(self, x)
#     337     return walk(t.right, x, path)
#     339 path = []
# --> 340 walk(self.root, x, path)
#     341 return path
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:335, in ShadowDecTree.predict_path.<locals>.walk(t, x, path)
#     333 if t.isleaf():
#     334     return None
# --> 335 if self.shouldGoLeftAtSplit(t.id, x[t.feature()]):
#     336     return walk(t.left, x, path)
#     337 return walk(t.right, x, path)
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ### Working code in Google Collab

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from dtreeviz import model
import pandas as pd

# Load dataset
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target

# Train classifier
clf = DecisionTreeClassifier()
clf.fit(X, y)

# Use the NEW dtreeviz.model() approach
viz = model(
    clf,
    X_train=X,
    y_train=y,
    feature_names=iris.feature_names,
    target_name="species",
    class_names=["setosa", "versicolor", "virginica"]
)

# Display the decision tree
viz.view()  # Or use .show_in_notebook() if in Jupyter
# Out:
# C:\Users\itsam\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File ~\anaconda3\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File ~\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File ~\anaconda3\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\utils.py:242, in DTreeVizRender._repr_svg_(self)
#     241 def _repr_svg_(self):
# --> 242     return self.svg()
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\utils.py:246, in DTreeVizRender.svg(self)
#     244 def svg(self):
#     245     """Render tree as svg and return svg text."""
# --> 246     svgfilename = self.save_svg()
#     247     with open(svgfilename, encoding='UTF-8') as f:
#     248         svg = f.read()
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\utils.py:266, in DTreeVizRender.save_svg(self)
#     264 tmp = tempfile.gettempdir()
#     265 svgfilename = os.path.join(tmp, f"DTreeViz_{os.getpid()}.svg")
# --> 266 self.save(svgfilename)
#     267 return svgfilename
#
# File ~\anaconda3\Lib\site-packages\dtreeviz\utils.py:294, in DTreeVizRender.save(self, filename)
#     292     graphviz.backend.run(cmd, capture_output=True, check=True, quiet=False)
#     293 else:
# --> 294     graphviz.backend.execute.run_check(cmd, capture_output=True, check=True, quiet=False)
#     296 if filename.endswith(".svg"):
#     297     # now merge in referenced SVG images to make all-in-one file
#     298     with open(filename, encoding='UTF-8') as f:
#
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH

# %%
# !choco install graphviz
# Out:
# 'choco' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\itsam\anaconda3\lib\site-packages (0.21)
# Note: you may need to restart the kernel to use updated packages.
